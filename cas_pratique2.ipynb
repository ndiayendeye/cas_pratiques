# %%
import numpy as np
import pandas as pd

# %%
Notes=pd.read_excel("examens.xlsx")
Notes
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique   Maths 1  \
# 0    DIALLO     Ibrahima      18.100      14.300           13    13.600
# 1        BA   Souleymane      19.700      17.600           16    16.000
# 2      BEYE      Alioune       4.750       4.300           10     8.602
# 3     BIAYE      Babacar      15.200      10.600           16    15.100
# 4     BALDE      Mamadou       4.700       7.100           15    13.150
# 5    CAMARA  Khadidiatou      13.700      11.100           10    10.252
# 6     CISSE          Awa      16.500      15.600           13    16.450
# 7     CISSE      Ousmane      15.100       6.700           10    12.800
# 8    DIAGNE        Marie      17.250      14.700           15    16.900
# 9      DIAW         Omar       2.900       8.600           15    10.000
# 10   DIATTA      Justine       6.798      10.800           16     3.700
# 11   DIALLO       Moussa       0.000       0.000            0     1.900
# ...

# %% [markdown]
# ## Question 2:

# %%
Tableau=Notes[Notes.columns[2:]].values
Tableau
# Out:
# array([[18.1  , 14.3  , 13.   , 13.6  , 15.8  , 14.   , 11.5  , 16.   ,
#         16.   , 15.2  , 14.4  , 10.   , 17.   , 10.4  , 10.   ],
#        [19.7  , 17.6  , 16.   , 16.   , 19.   , 16.6  , 16.8  ,  0.   ,
#         20.   , 20.   , 16.   , 12.   , 16.   , 15.6  , 18.   ],
#        [ 4.75 ,  4.3  , 10.   ,  8.602, 11.4  ,  5.4  ,  8.4  ,  6.   ,
#          2.8  ,  6.1  ,  8.4  ,  7.   , 11.   , 15.6  , 11.   ],
#        [15.2  , 10.6  , 16.   , 15.1  , 15.   , 18.6  ,  8.2  ,  8.   ,
#         15.8  , 14.8  , 14.4  , 11.   , 13.   ,  9.4  , 14.   ],
#        [ 4.7  ,  7.1  , 15.   , 13.15 , 16.   , 10.6  , 11.   , 16.   ,
#          7.2  , 14.9  , 13.4  ,  8.   , 12.   , 14.8  , 15.   ],
#        [13.7  , 11.1  , 10.   , 10.252,  9.752,  9.4  , 12.9  , 20.   ,
#          8.8  ,  7.6  , 11.6  ,  7.   , 15.   ,  8.2  ,  7.   ],
#        [16.5  , 15.6  , 13.   , 16.45 , 14.6  , 15.8  , 10.3  ,  6.   ,
#         17.   , 16.1  , 14.8  , 10.   , 12.   , 13.6  , 10.   ],
# ...

# %% [markdown]
# ## physique

# %%
NotesPhysique=Tableau[:,0:3]
Coef1=[2.5,2.5,1]
for j in range(len(NotesPhysique)):
    for i in range(0,3):
        NotesPhysique[j,i]=NotesPhysique[j,i]*Coef1[i]
NotesPhysique
moyen_Phy=np.sum(NotesPhysique,axis=1)/6

#Validation 
V1=[]
credit_Phy=[]
for i in range(len(moyen_Phy)):
    if moyen_Phy[i] >=10:
        V1.append("V")
        credit_Phy.append(12)
        

    else:
        V1.append("NV")
        credit_Phy.append(0)
V1
# Out:
# ['V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# ## MATHS

# %%
NotesMaths=Tableau[:,3:5]

Coef2=[2.5,2.5]
for j in range(len(NotesMaths)):
    for i in range(2):
        NotesMaths[j,i]=NotesMaths[j,i]*Coef2[i]
moyen_Maths=np.sum(NotesMaths, axis=1)/5
V2=[]
credit_Math=[]
for i in range(len(moyen_Maths)):
    if moyen_Maths[i] >=10:
        V2.append("V")
        credit_Math.append(10)
    else:
        V2.append("NV")
        credit_Math.append(0)
V2
# Out:
# ['V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# ## Moyenne Chimie

# %%
NotesChimie=Tableau[:,5:8]
Coef3=[2.5,2.5,1]
for j in range(len(NotesChimie)):
    for i in range(3):
        NotesChimie[j,i]=NotesChimie[j,i]*Coef3[i]
moyen_Chimie=np.sum(NotesChimie, axis=1)/6
V3=[]
credit_Chimie=[]
for i in range(len(moyen_Chimie)):
    if moyen_Chimie[i] >=10:
        V3.append("V")
        credit_Chimie.append(12)
    else:
        V3.append("NV")
        credit_Chimie.append(0)
V3
# Out:
# ['V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# ## Moyenne Infos

# %%
NotesInfos=Tableau[:,8:10]
Coef4=[2.5,2.5]
for j in range(len(NotesInfos)):
    for i in range(2):
        NotesInfos[j,i]=NotesInfos[j,i]*Coef4[i]

moyenne_Infos=np.sum(NotesInfos, axis=1)/5
V4=[]
credit_Info=[]
for i in range(len(moyenne_Infos)):
    if moyenne_Infos[i] >=10:
        V4.append("V")
        credit_Info.append(10)
    else:
        V4.append("NV")
        credit_Info.append(0)
V4
# Out:
# ['V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# ## Moyenne Outils_Base

# %%
notes_Ob=Tableau[:,10:13]
Coef5=[1.5,1.5,1]
for j in range(len(notes_Ob)):
    for i in range(3):
        notes_Ob[j,i]=notes_Ob[j,i]*Coef5[i]
moyenne_Ob=np.sum(notes_Ob, axis=1)/4
V5=[]
credit_Ob=[]
for i in range(len(moyenne_Ob)):
    if moyenne_Ob[i] >=10:
        V5.append("V")
        credit_Ob.append(8)

    else:
        V5.append("NV")
        credit_Ob.append(0)
V5
# Out:
# ['V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V']

# %% [markdown]
# # Moyenne Graphique

# %%
notes_GR=Tableau[:,13:]
Coef6=[2,2]
for j in range(len(notes_GR)):
    for i in range(2):
        notes_GR[j,i]=notes_GR[j,i]*Coef6[i]
moyenne_GR=np.sum(notes_GR, axis=1)/4
V6=[]
credit_G=[]
for i in range(len(moyenne_GR)):
    if moyenne_GR[i] >=10:
        V6.append("V")
        credit_G.append(8)
    else:
        V6.append("NV")
        credit_G.append(0)
V6
# Out:
# ['V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V',
#  'V',
#  'NV',
#  'NV',
#  'NV',
#  'V',
#  'V',
#  'V']

# %%
Notes
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique   Maths 1  \
# 0    DIALLO     Ibrahima      18.100      14.300           13    13.600
# 1        BA   Souleymane      19.700      17.600           16    16.000
# 2      BEYE      Alioune       4.750       4.300           10     8.602
# 3     BIAYE      Babacar      15.200      10.600           16    15.100
# 4     BALDE      Mamadou       4.700       7.100           15    13.150
# 5    CAMARA  Khadidiatou      13.700      11.100           10    10.252
# 6     CISSE          Awa      16.500      15.600           13    16.450
# 7     CISSE      Ousmane      15.100       6.700           10    12.800
# 8    DIAGNE        Marie      17.250      14.700           15    16.900
# 9      DIAW         Omar       2.900       8.600           15    10.000
# 10   DIATTA      Justine       6.798      10.800           16     3.700
# 11   DIALLO       Moussa       0.000       0.000            0     1.900
# ...

# %%
Notes.insert(5,"UE_PHysique",V1,allow_duplicates=False)
Notes.insert(8,"UE_MATH",V2,allow_duplicates=False)
Notes.insert(12,"UE_CHIMIE",V3,allow_duplicates=False)
Notes.insert(15,"UE_INFO",V4,allow_duplicates=False)
Notes.insert(19,"UE_OUTILS_B",V5,allow_duplicates=False)
Notes.insert(22,"UE_GRAPH",V6,allow_duplicates=False)
Notes
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique UE_PHysique  \
# 0    DIALLO     Ibrahima      18.100      14.300           13           V
# 1        BA   Souleymane      19.700      17.600           16           V
# 2      BEYE      Alioune       4.750       4.300           10          NV
# 3     BIAYE      Babacar      15.200      10.600           16           V
# 4     BALDE      Mamadou       4.700       7.100           15          NV
# 5    CAMARA  Khadidiatou      13.700      11.100           10           V
# 6     CISSE          Awa      16.500      15.600           13           V
# 7     CISSE      Ousmane      15.100       6.700           10           V
# 8    DIAGNE        Marie      17.250      14.700           15           V
# 9      DIAW         Omar       2.900       8.600           15          NV
# 10   DIATTA      Justine       6.798      10.800           16          NV
# 11   DIALLO       Moussa       0.000       0.000            0          NV
# ...

# %% [markdown]
# # Trie des noms et prenoms

# %%
Nom_Prenom=Notes.sort_values(by=["Nom","Prénom"],ascending=[True,True])
Nom_Prenom
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique UE_PHysique  \
# 1        BA   Souleymane      19.700      17.600           16           V
# 4     BALDE      Mamadou       4.700       7.100           15          NV
# 2      BEYE      Alioune       4.750       4.300           10          NV
# 3     BIAYE      Babacar      15.200      10.600           16           V
# 5    CAMARA  Khadidiatou      13.700      11.100           10           V
# 6     CISSE          Awa      16.500      15.600           13           V
# 7     CISSE      Ousmane      15.100       6.700           10           V
# 8    DIAGNE        Marie      17.250      14.700           15           V
# 0    DIALLO     Ibrahima      18.100      14.300           13           V
# 11   DIALLO       Moussa       0.000       0.000            0          NV
# 16     DIAO      Mariama      12.700      17.000           16           V
# 10   DIATTA      Justine       6.798      10.800           16          NV
# ...

# %% [markdown]
# # Q5:Enregistrement dans le fichier Excel

# %%
Resultats=pd.ExcelWriter("Deliberation.xlsx", engine="xlsxwriter")
Notes.to_excel(Resultats,"Resultats_Annuelle", index=False)
Resultats.save()

# %% [markdown]
# ## Q6

# %%
MoyG=(moyen_Phy+moyen_Maths+moyen_Chimie+moyenne_Infos+moyenne_Ob+moyenne_GR)/(6)
MoyG
# Out:
# array([13.80972222, 16.82083333,  8.07725   , 13.45694444, 11.77222222,
#        10.192     , 13.93194444, 11.05694444, 15.03680556, 12.26416667,
#         8.97069444,  0.15833333, 11.54236111, 10.73333333, 13.46041667,
#        12.18472222, 16.        , 14.54791667, 13.69791667,  0.        ,
#        17.25666667,  2.85138889, 16.64861111, 10.05833333, 12.17291667,
#         2.81527778, 13.55666667,  8.96597222, 16.10597222,  0.15833333,
#         9.16388889, 12.08472222,  0.        ,  0.15833333, 13.        ,
#        13.15972222, 12.19861111, 11.73472222,  0.        ,  1.60555556,
#         9.70833333, 12.60416667, 13.2875    , 14.10277778])

# %%
totalCredit=[]
for i in range(len(MoyG)):
    totalCredit.append(credit_Phy[i]+credit_Math[i]+credit_Chimie[i]+credit_Info[i]+credit_Ob[i]+credit_G[i])
totalCredit
# Out:
# [60,
#  60,
#  18,
#  60,
#  48,
#  42,
#  60,
#  52,
#  60,
#  48,
#  28,
#  0,
#  50,
#  50,
#  60,
#  48,
#  60,
#  60,
#  60,
#  0,
#  60,
#  0,
#  60,
#  48,
#  60,
#  0,
#  60,
#  16,
#  60,
#  0,
#  26,
#  60,
#  0,
#  0,
#  60,
#  60,
#  60,
#  60,
#  0,
#  0,
#  32,
#  60,
#  60,
#  60]

# %%
#Insertion dans le dataframe

Notes.insert(23,"Moy_Annuelle",MoyG,allow_duplicates=False)
Notes.insert(24,"TotalCredits",totalCredit,allow_duplicates=False)
Notes
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique UE_PHysique  \
# 0    DIALLO     Ibrahima      18.100      14.300           13           V
# 1        BA   Souleymane      19.700      17.600           16           V
# 2      BEYE      Alioune       4.750       4.300           10          NV
# 3     BIAYE      Babacar      15.200      10.600           16           V
# 4     BALDE      Mamadou       4.700       7.100           15          NV
# 5    CAMARA  Khadidiatou      13.700      11.100           10           V
# 6     CISSE          Awa      16.500      15.600           13           V
# 7     CISSE      Ousmane      15.100       6.700           10           V
# 8    DIAGNE        Marie      17.250      14.700           15           V
# 9      DIAW         Omar       2.900       8.600           15          NV
# 10   DIATTA      Justine       6.798      10.800           16          NV
# 11   DIALLO       Moussa       0.000       0.000            0          NV
# ...

# %%
tri=Notes.sort_values(by=["TotalCredits","Nom","Prénom"],ascending=[False,True,True])
tri
# Out:
#         Nom       Prénom  Physique 1  Physique 2  TP Physique UE_PHysique  \
# 1        BA   Souleymane      19.700      17.600           16           V
# 3     BIAYE      Babacar      15.200      10.600           16           V
# 6     CISSE          Awa      16.500      15.600           13           V
# 8    DIAGNE        Marie      17.250      14.700           15           V
# 0    DIALLO     Ibrahima      18.100      14.300           13           V
# 16     DIAO      Mariama      12.700      17.000           16           V
# 14     DIOP      Birahim      11.250      11.680           15           V
# 17     FALL     Ibrahima      13.550      16.300           13           V
# 18     FAYE         Ngor      13.150      17.800           10           V
# 20     KEBE     Maimouna      19.400      20.000           13           V
# 22       LY       Ramata      16.900      12.800           16           V
# 24    MBAYE       Saliou       7.810      11.000           13           V
# ...

# %%
nom=Notes.Nom[np.where(Notes.Moy_Annuelle.values==Notes.Moy_Annuelle.values.max())[0]]
prenom=Notes.Prénom[np.where(Notes.Moy_Annuelle.values==Notes.Moy_Annuelle.values.max())[0]]
moy_major=Notes.Moy_Annuelle[np.where(Notes.Moy_Annuelle.values==Notes.Moy_Annuelle.values.max())[0]]
print("Le major est:",prenom,nom,"avec une moyenne annuelle de",moy_major)
# Out:
# Le major est: 20    Maimouna
# Name: Prénom, dtype: object 20    KEBE
# Name: Nom, dtype: object avec une moyenne annuelle de 20    17.256667
# Name: Moy_Annuelle, dtype: float64

# %% [markdown]
# # Question 7:

# %%
v_ph=len(np.where(Notes["UE_PHysique"].values=="V")[0])
v_math=len(np.where(Notes["UE_MATH"].values=="V")[0])
v_ch=len(np.where(Notes["UE_CHIMIE"].values=="V")[0])
v_info=len(np.where(Notes["UE_INFO"].values=="V")[0])
v_out_b=len(np.where(Notes["UE_OUTILS_B"].values=="V")[0])
v_gr=len(np.where(Notes["UE_GRAPH"].values=="V")[0])
print("Le nombre d'etudiants qui ont validés la physique est:",v_ph)
print("Le nombre d'etudiants qui ont validés la physique est:",v_math)
print("Le nombre d'etudiants qui ont validés la physique est:",v_ch)
print("Le nombre d'etudiants qui ont validés la physique est:",v_info)
print("Le nombre d'etudiants qui ont validés la physique est:",v_out_b)
print("Le nombre d'etudiants qui ont validés la physique est:",v_gr)
# Out:
# Le nombre d'etudiants qui ont validés la physique est: 28
# Le nombre d'etudiants qui ont validés la physique est: 31
# Le nombre d'etudiants qui ont validés la physique est: 30
# Le nombre d'etudiants qui ont validés la physique est: 30
# Le nombre d'etudiants qui ont validés la physique est: 33
# Le nombre d'etudiants qui ont validés la physique est: 32

# %% [markdown]
# # Question 8

# %%
import matplotlib.pyplot as plt
x=["Physique","Mathématique", "Chimie","Informatique","OutilsBases","Graphique"]
y=[v_ph,v_math,v_ch,v_info,v_out_b,v_gr]
fig,axe=plt.subplots(figsize=(13,9))
plt.plot(x,y)
plt.grid()
plt.title("statistique")
plt.show()

# %%
import xlwings as xw
c=xw.Book("Deliberation.xlsx")
c.sheets.add("Resutats finals")
R=c.sheets["Resutats finals"]
axe=axe.get_figure()
R.pictures.add(axe,name="Resultas_Examen",update=True)
# Out:
# <Picture 'Resultas_Examen' in <Sheet [Deliberation.xlsx]Resutats finals>>
